# %%
import pandas as pd
import glob
from datetime import timedelta, datetime

exports_activity_passing_no_parmaters =  pd.read_csv(r'D:\activity.csv')

exports_activity_passing_no_parmaters['Date'] =  pd.to_datetime(exports_activity_passing_no_parmaters['Date'])
#exports_activity_passing_no_parmaters['Date'] = exports_activity_passing_no_parmaters['Date'].datetime.date
exports_activity_passing_no_parmaters['just_date'] = exports_activity_passing_no_parmaters['Date'].dt.date
#, format = "%Y-%M-%d"

#print(exports_activity_passing_no_parmaters['Date'])
#print(exports_activity_passing_no_parmaters['just_date'])

max_date = exports_activity_passing_no_parmaters["Date"].max()
latest_date = max_date.date()
min_date = exports_activity_passing_no_parmaters["Date"].min()
oldest_date = min_date.date()
#print(latest_date)
#print(oldest_date)
date_range = []
date_range.append(oldest_date)

while oldest_date < latest_date :
    oldest_date = oldest_date + timedelta(days=1)
    date_range.append(oldest_date)

for dates in date_range:
    daily_wise_file_df = exports_activity_passing_no_parmaters.loc[exports_activity_passing_no_parmaters['just_date'] == dates]
    path = r'D:\Mandrill_Exports\mandrill_daily_files\date_wise_files\test_foldermandrill_data'
    file_name = path + "mandrill_data" + str(dates) + ".csv"
    daily_wise_file_df.to_csv(file_name, index=False)
    
path =r'D:\Mandrill_Exports\mandrill_daily_files\date_wise_files'
filenames = glob.glob(path + "/*.csv")

dfs = []
counts_original_df = []
counts_downsizing = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, parse_dates=['just_date']))
big_frame = pd.concat(dfs, ignore_index=True)
print(big_frame.shape)
big_grame.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-323f0b6d14f2> in <module>
#      30     path = r'D:\Mandrill_Exports\mandrill_daily_files\date_wise_files\test_folder'
#      31     file_name = path + "mandrill_data" + str(dates) + ".csv"
# ---> 32     daily_wise_file_df.to_csv(file_name, index=False)
#      33
#      34 path =r'D:\Mandrill_Exports\date_wise_files'
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ...

# %%
import pandas as pd
from datetime import timedelta, datetime

exports_activity_passing_no_parmaters =  pd.read_csv(r'D:\activity.csv')

exports_activity_passing_no_parmaters['Date'] =  pd.to_datetime(exports_activity_passing_no_parmaters['Date'])
#exports_activity_passing_no_parmaters['Date'] = exports_activity_passing_no_parmaters['Date'].datetime.date
exports_activity_passing_no_parmaters['just_date'] = exports_activity_passing_no_parmaters['Date'].dt.date
#, format = "%Y-%M-%d"

#print(exports_activity_passing_no_parmaters['Date'])
#print(exports_activity_passing_no_parmaters['just_date'])

max_date = exports_activity_passing_no_parmaters["Date"].max()
latest_date = max_date.date()
min_date = exports_activity_passing_no_parmaters["Date"].min()
oldest_date = min_date.date()
#print(latest_date)
#print(oldest_date)
date_range = []
date_range.append(oldest_date)

while oldest_date < latest_date :
    oldest_date = oldest_date + timedelta(days=1)
    date_range.append(oldest_date)

for dates in date_range:
    daily_wise_file_df = exports_activity_passing_no_parmaters.loc[exports_activity_passing_no_parmaters['just_date'] == dates]
    path = r'D:\Mandrill_Exports\mandrill_daily_files\date_wise_files\test_folder'
    file_name = path + "mandrill_data" + str(dates) + ".csv"
    daily_wise_file_df.to_csv(file_name, index=False)

# %%
file_twenty_first_june = pd.read_csv(r"D:\Mandrill_Exports\mandrill_daily_files\date_wise_files\test_foldermandrill_data2021-06-21.csv")

# %%
file_twenty_first_june.loc[file_twenty_first_june["Opens"] != 0]
# Out:
#                     Date               Email Address           Sender  \
# 0    2021-06-21 06:38:53      tpkgroup@outlook.co.th  news@skidos.com
# 1    2021-06-21 01:20:34   elisaorozco9721@gmail.com  news@skidos.com
# 19   2021-06-21 09:35:14   chrishanna2016@icloud.com  news@skidos.com
# 21   2021-06-21 00:16:56          pacena01@gmail.com  news@skidos.com
# 29   2021-06-21 00:20:21   maxwellcherilyn@gmail.com  news@skidos.com
# ..                   ...                         ...              ...
# 725  2021-06-21 00:02:20  queenofhearts5@optimum.net  news@skidos.com
# 728  2021-06-21 05:44:06   Johnsonromeo381@gmail.com  news@skidos.com
# 730  2021-06-21 04:45:28        tuuyen.afi@gmail.com  news@skidos.com
# 732  2021-06-21 02:42:47       mlramos1283@gmail.com  news@skidos.com
# 736  2021-06-21 05:25:50     poissonenlair@gmail.com  news@skidos.com
#
#                                  Subject Status  Tags         Subaccount  \
# ...

# %%
date_range
# Out:
# [datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 27),
#  datetime.date(2021, 3, 28),
#  datetime.date(2021, 3, 29),
#  datetime.date(2021, 3, 30),
#  datetime.date(2021, 3, 31),
#  datetime.date(2021, 4, 1),
#  datetime.date(2021, 4, 2),
#  datetime.date(2021, 4, 3),
#  datetime.date(2021, 4, 4),
#  datetime.date(2021, 4, 5),
#  datetime.date(2021, 4, 6),
#  datetime.date(2021, 4, 7),
#  datetime.date(2021, 4, 8),
#  datetime.date(2021, 4, 9),
#  datetime.date(2021, 4, 10),
#  datetime.date(2021, 4, 11),
#  datetime.date(2021, 4, 12),
#  datetime.date(2021, 4, 13),
#  datetime.date(2021, 4, 14),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 17),
#  datetime.date(2021, 4, 18),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 23),
# ...

# %%
# def _getToday():
#         return datetime.date.today().strftime("%Y%m%d")

for dates in date_range:
    daily_wise_file_df = exports_activity_passing_no_parmaters.loc[exports_activity_passing_no_parmaters['just_date'] == dates]
    outpath = r'C:\test'
    filename = "test" % ("filename",  ,".csv")

    print(outpath + "\\" + filename)

# %%
for dates in date_range:
    daily_wise_file_df = exports_activity_passing_no_parmaters.loc[exports_activity_passing_no_parmaters['just_date'] == dates]
    path = "D:\Mandrill_Exports\mandrill_daily_files\date_wise_files"
    file_name = path + "mandrill_data" + str(dates) + ".csv"
    daily_wise_file_df.to_csv(file_name, index=False)

# %%
date_range = []
date_range.append(oldest_date)

# %%
while oldest_date < latest_date :
    oldest_date = oldest_date + timedelta(days=1)
    date_range.append(oldest_date)

# %%
date_range
# Out:
# [datetime.date(2021, 6, 21)]

# %%
exports_activity_passing_no_parmaters =  pd.read_csv(r'D:\activity.csv')

# %%
#exports_activity_passing_no_parmaters[100:150]

# %%
exports_activity_passing_no_parmaters.dtypes
# Out:
# Date              object
# Email Address     object
# Sender            object
# Subject           object
# Status            object
# Tags             float64
# Subaccount        object
# Opens              int64
# Clicks             int64
# Bounce Detail     object
# dtype: object

# %%
exports_activity_passing_no_parmaters['Date'] =  pd.to_datetime(exports_activity_passing_no_parmaters['Date'])

# %%
exports_activity_passing_no_parmaters['Date']
# Out:
# 0       2021-06-09 23:45:53
# 1       2021-05-26 03:20:29
# 2       2021-06-18 13:07:33
# 3       2021-06-15 16:48:03
# 4       2021-06-16 18:33:57
#                 ...
# 61013   2021-05-30 07:58:49
# 61014   2021-05-29 15:53:49
# 61015   2021-06-20 05:26:59
# 61016   2021-06-14 02:48:23
# 61017   2021-05-29 11:46:38
# Name: Date, Length: 61018, dtype: datetime64[ns]

# %%
latest_date = max_date.date()

# %%
latest_date
# Out:
# datetime.date(2021, 6, 21)

# %%
min_date = exports_activity_passing_no_parmaters["Date"].min()

# %%
min_date
# Out:
# Timestamp('2021-03-23 00:03:19')

# %%
oldest_date = min_date.date()

# %%
oldest_date
# Out:
# datetime.date(2021, 6, 22)

# %%
date_range=[]

# %%
date_range.append(oldest_date)

# %%
while oldest_date < latest_date :
    oldest_date = oldest_date + timedelta(days=1)
    date_range.append(oldest_date)

# %%
print(date_range)
# Out:
# [Timestamp('2021-06-22 00:03:19'), datetime.date(2021, 6, 22)]

# %%
exports_activity_passing_no_parmaters = exports_activity_passing_no_parmaters.loc[(exports_activity_passing_no_parmaters['Date'] >= '2021-04-01 00:00:00')
                     & (exports_activity_passing_no_parmaters['Date'] < '2021-04-31 23:59:59')]

# %%
exports_activity_passing_no_parmaters[100:130]
# Out:
#                      Date                         Email Address  \
# 2026  2021-04-19 21:53:49                widemanlove@icloud.com
# 2092  2021-04-09 03:48:01           Annabelly.Melnyk@icloud.com
# 2108  2021-04-12 14:44:05               federica.bettoni@me.com
# 2116  2021-04-24 00:15:57                baslater1970@gmail.com
# 2124  2021-04-01 08:48:52               kimbella1595@icloud.com
# 2130  2021-04-10 03:20:53              verdarobinson@icloud.com
# 2143  2021-04-07 16:17:41                          vika@mail.ru
# 2164  2021-04-11 02:08:46           jacobnavarro1776@icloud.com
# 2177  2021-04-13 03:36:09             masonbentley30@icloud.com
# 2185  2021-04-09 19:27:14             ap_rodriguez23@icloud.com
# 2190  2021-04-03 21:04:55             toyochiatsushi@icloud.com
# 2206  2021-04-15 16:39:01             valentin032016@icloud.com
# 2230  2021-04-24 15:31:41                    taraderr@yahoo.com
# 2310  2021-04-07 00:52:12               Kirstanbrown@icloud.com
# ...
