# %%
import glob
import pandas as pd
import datetime

path =r'D:\Data\june_reset_password_dailyfiles'
filenames = glob.glob(path + "/*.csv")

dfs = []
counts_original_df = []
counts_downsizing = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, parse_dates=['just_date']))
big_frame = pd.concat(dfs, ignore_index=True)
big_frame[30:60]
#big_frame.groupby(pd.Grouper(key='just_date',freq='D')).sum()
# Out:
#                    Date                   Email Address           Sender  \
# 30  2021-06-01 23:16:01    thomazguilherme365@gmail.com  news@skidos.com
# 31  2021-06-01 14:57:17            tclark1824@gmail.com  news@skidos.com
# 32  2021-06-01 01:05:08            jen.r.carr@gmail.com  news@skidos.com
# 33  2021-06-01 20:57:14              lonreia@icloud.com  news@skidos.com
# 34  2021-06-01 14:56:20        pepi.tree_ts@yopmail.com  news@skidos.com
# 35  2021-06-01 00:47:56          jennivicente@gmail.com  news@skidos.com
# 36  2021-06-01 02:27:58               sartal7@gmail.com  news@skidos.com
# 37  2021-06-01 17:31:21               takey62@gmail.com  news@skidos.com
# 38  2021-06-01 13:40:34   juannavarrogarcia@hotmail.com  news@skidos.com
# 39  2021-06-01 13:16:33            sdk.vcss@yopmail.com  news@skidos.com
# 40  2021-06-01 15:00:38             es.tree@yopmail.com  news@skidos.com
# 41  2021-06-01 20:31:42         lbdudley100@hotmail.com  news@skidos.com
# ...

# %%
big_frame.groupby(pd.Grouper(key='just_date',freq='D')).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-181-922e6af64dd3> in <module>
# ----> 1 big_frame.groupby(pd.Grouper(key='just_date',freq='D')).sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
# ...

# %%
big_frame.shape
# Out:
# (37961, 11)

# %%
group_obj = big_frame.groupby(pd.Grouper(key='just_date',freq='D'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-fa4ed695c414> in <module>
# ----> 1 group_obj = big_frame.groupby(pd.Grouper(key='just_date',freq='D'))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
# ...

# %%
big_frame[['just_date', 'Subject']].value_counts().sort_index()
# Out:
# just_date   Subject
# 2021-06-01  Bem-vindo ao Skidos!                   61
#             Benvenuto a skidos                     17
#             Bienvenue à skidos                     29
#             Forgotten your password?               41
#             Glemt passord?                          2
#                                                    ..
# 2021-06-21  Willkommen bei Skidos!                  5
#             [Skidos] New password                  52
#             [Skidos] Please reset your password    91
#             [Skidos] Redefina sua senha             2
#             ¡Bienvenido/a a SKIDOS!                12
# Length: 447, dtype: int64

# %%
big_frame.set_index('just_date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-179-76f504b5a5fe> in <module>
# ----> 1 big_frame.set_index('just_date', inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['just_date'] are in the columns"

# %%
import glob
import pandas as pd
import datetime

path =r'D:\Data\june_reset_password_dailyfiles'
filenames = glob.glob(path + "/*.csv")

dfs = []
counts_original_df = []
counts_downsizing = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, parse_dates=['just_date']))
big_frame = pd.concat(dfs, ignore_index=True)

#big_frame= big_frame.loc[big_frame["Subject"].str.contains('reset your password')]
big_frame.groupby(pd.Grouper(key='just_date',freq='D')).sum()
# Out:
#             Tags  Opens  Clicks
# just_date
# 2021-06-01   0.0    174      66
# 2021-06-02   0.0     91      64
# 2021-06-03   0.0    129      47
# 2021-06-04   0.0    155      62
# 2021-06-05   0.0    163      63
# 2021-06-06   0.0    182      64
# 2021-06-07   0.0    102      42
# 2021-06-08   0.0    124      57
# 2021-06-09   0.0    143      61
# 2021-06-10   0.0    104      52
# 2021-06-11   0.0    204      82
# 2021-06-12   0.0    286     116
# 2021-06-13   0.0    450     184
# 2021-06-14   0.0    363     168
# 2021-06-15   0.0    284     121
# 2021-06-16   0.0    234      94
# 2021-06-17   0.0    330     148
# 2021-06-18   0.0    212      92
# 2021-06-19   0.0    366     121
# 2021-06-20   0.0    391     165
# 2021-06-21   0.0     61      29

# %%
big_frame[['Subject', 'just_date']].value_counts().sort_index()
# Out:
# Subject                              just_date
# [Skidos] Please reset your password  2021-06-01    175
#                                      2021-06-02    128
#                                      2021-06-03    123
#                                      2021-06-04    127
#                                      2021-06-05    134
#                                      2021-06-06    170
#                                      2021-06-07    121
#                                      2021-06-08    117
#                                      2021-06-09    123
#                                      2021-06-10    118
#                                      2021-06-11    223
#                                      2021-06-12    236
#                                      2021-06-13    307
#                                      2021-06-14    282
#                                      2021-06-15    242
#                                      2021-06-16    206
# ...

# %%
big_frame[['Subject', 'just_date']].value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Subject,just_date'>

# %%
result = big_frame.join(group_object)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-155-a27dcd6f3be2> in <module>
# ----> 1 result = big_frame.join(group_object)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8108         5  K5  A5  NaN
#    8109         """
# -> 8110         return self._join_compat(
#    8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8133                     sort=sort,
#    8134                 )
# -> 8135             return merge(
#    8136                 self,
#    8137                 other,
#
# ...

# %%
import glob
import pandas as pd
import datetime

path =r'D:\Data\june_reset_password_dailyfiles'
filenames = glob.glob(path + "/*.csv")

dfs = []
counts_original_df = []
counts_downsizing = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, parse_dates=['just_date']))
big_frame = pd.concat(dfs, ignore_index=True)


daily_grouped_object = big_frame.groupby(pd.Grouper(key='just_date',freq='D')).sum()

# %%
big_frame.dtypes
# Out:
# Date                     object
# Email Address            object
# Sender                   object
# Subject                  object
# Status                   object
# Tags                    float64
# Subaccount               object
# Opens                     int64
# Clicks                    int64
# Bounce Detail            object
# just_date        datetime64[ns]
# dtype: object

# %%
big_frame['just_date']
# Out:
# 0       2021-06-01
# 1       2021-06-01
# 2       2021-06-01
# 3       2021-06-01
# 4       2021-06-01
#            ...
# 37956   2021-06-21
# 37957   2021-06-21
# 37958   2021-06-21
# 37959   2021-06-21
# 37960   2021-06-21
# Name: just_date, Length: 37961, dtype: datetime64[ns]

# %%
daily_grouped_object = big_frame.groupby(pd.Grouper(key='just_date',freq='D')).sum()

# %%
big_frame['Subject'].value_counts()
# Out:
# Welcome to Skidos!                               23519
# [Skidos] Please reset your password               4033
# [Skidos] New password                             2469
# Bem-vindo ao Skidos!                              1506
# ¡Bienvenido/a a SKIDOS!                           1078
# Bienvenue à skidos                                 848
# Velkommen til Skidos!                              837
# Forgotten your password?                           760
# Välkommen till Skidos!                             530
# Benvenuto a skidos                                 521
# Welcome to Skidos NL!                              497
# Willkommen bei Skidos!                             493
# [Skidos] Redefina sua senha                        208
# Restablecer contraseña                             137
# Har du glemt din adgangskode?                       83
# Glemt passord?                                      72
# Glömt lösenord?                                     64
# ...

# %%
big_frame['Subject'].value_counts(normalize=True)
# Out:
# Welcome to Skidos!                               0.619557
# [Skidos] Please reset your password              0.106241
# [Skidos] New password                            0.065040
# Bem-vindo ao Skidos!                             0.039672
# ¡Bienvenido/a a SKIDOS!                          0.028398
# Bienvenue à skidos                               0.022339
# Velkommen til Skidos!                            0.022049
# Forgotten your password?                         0.020021
# Välkommen till Skidos!                           0.013962
# Benvenuto a skidos                               0.013725
# Welcome to Skidos NL!                            0.013092
# Willkommen bei Skidos!                           0.012987
# [Skidos] Redefina sua senha                      0.005479
# Restablecer contraseña                           0.003609
# Har du glemt din adgangskode?                    0.002186
# Glemt passord?                                   0.001897
# ...

# %%
big_frame['just_date'].value_counts()
# Out:
# 2021-06-20    2282
# 2021-06-19    2251
# 2021-06-14    2130
# 2021-06-13    2115
# 2021-06-17    2000
# 2021-06-12    1969
# 2021-06-11    1933
# 2021-06-15    1932
# 2021-06-18    1876
# 2021-06-16    1865
# 2021-06-06    1840
# 2021-06-05    1750
# 2021-06-03    1726
# 2021-06-07    1692
# 2021-06-01    1658
# 2021-06-09    1657
# 2021-06-02    1648
# 2021-06-10    1646
# 2021-06-08    1635
# 2021-06-04    1619
# 2021-06-21     737
# Name: just_date, dtype: int64

# %%
expected_df = big_frame.groupby(pd.Grouper(key='just_date',freq='D'))

# %%
import glob
import pandas as pd
import datetime

mydateparser = lambda x: pd.datetime.strptime(x, "%Y-%m-%d")
#df = pd.read_csv("file.csv", sep='\t', names=['date_column', 'other_column'], parse_dates=['date_column'], date_parser=mydateparser)
# get data file names
path =r'D:\Data\june_reset_password_dailyfiles'
filenames = glob.glob(path + "/*.csv")

dfs = []
counts_original_df = []
counts_downsizing = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, parse_dates=['just_date'], date_parser=mydateparser))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)


# big_frame['just_date']=pd.to_datetime(big_frame['just_date'])

#big_frame['string_just_date'] = big_frame.just_date.strftime("%Y-%M-%d")

#big_frame['DateStr'] = big_frame['Date'].dt.strftime('%Y-%M-%d')
#big_frame['just_date'] = pd.to_datetime(big_frame['just_date'], errors='coerce')

#big_frame['DateStr'] = big_frame['just_date'].dt.strftime('%Y-%M-%d')
#big_frame.set_index('just_date', inplace=True)
#print(big_frame['DateStr'])

#big_frame.head()
#print(big_frame['just_date'])
#big_frame = big_frame[big_frame["Date"].isin(big_frame["just_date"])]
daily_reset_request_group = big_frame.groupby(["just_date", pd.Grouper(key="just_date",freq="D")])

#df['size'] = df.groupby('c')['type'].transform(len)

df.groupby(["just_date", "Subject"])["Subject"].transform("count")
#expected_df = big_frame.groupby(pd.Grouper(level='just_date',freq='D')) #for no.of counts by date.day

daily_reset_requests_df['Counts'] = daily_reset_requests_df['Subject'].value_counts()

daily_reset_requests_df.head()
# Out:
# <ipython-input-123-236dd7743920>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   mydateparser = lambda x: pd.datetime.strptime(x, "%Y-%m-%d")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-236dd7743920> in <module>
#      40 #expected_df = big_frame.groupby(pd.Grouper(level='just_date',freq='D')) #for no.of counts by date.day
#      41
# ---> 42 daily_reset_requests_df['Counts'] = daily_reset_requests_df['Subject'].value_counts()
#      43
#      44 daily_reset_requests_df.head()
#
# TypeError: 'DataFrameGroupBy' object does not support item assignment

# %%
import glob
import pandas as pd

# get data file names
path =r'D:\Data\june_reset_password_dailyfiles'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)
#big_frame.shape
# big_frame['just_date']=pd.to_datetime(big_frame['just_date'])
big_frame.set_index('just_date', inplace=True)

df = expected_df.groupby(pd.Grouper(level='just_date',freq='D')) #for no.of counts by date'
# Out:
# (37961, 11)

# %%
big_frame.head(50)
# Out:
#                    Date                     Email Address           Sender  \
# 0   2021-06-01 11:07:01             lindapull@comcast.net  news@skidos.com
# 1   2021-06-01 17:06:27   nayelisaucedo04012002@gmail.com  news@skidos.com
# 2   2021-06-01 19:55:54              antonina.olma@web.de  news@skidos.com
# 3   2021-06-01 04:19:48        anoushay.hussain@gmail.com  news@skidos.com
# 4   2021-06-01 13:41:10             m.atik1_c@yopmail.com  news@skidos.com
# 5   2021-06-01 17:34:26      jyothirmayee.ankam@gmail.com  news@skidos.com
# 6   2021-06-01 14:37:37  brendarochellewilkie14@gmail.com  news@skidos.com
# 7   2021-06-01 07:33:11                 re.kn@yopmail.com  news@skidos.com
# 8   2021-06-01 16:48:24                 123fool@gmail.com  news@skidos.com
# 9   2021-06-01 22:39:58                    ucools@msn.com  news@skidos.com
# 10  2021-06-01 01:34:24            katiemtz1011@gmail.com  news@skidos.com
# ...

# %%
big_frame.shape
# Out:
# (37961, 11)

# %%
big_frame.columns
# Out:
# Index(['Date', 'Email Address', 'Sender', 'Subject', 'Status', 'Tags',
#        'Subaccount', 'Opens', 'Clicks', 'Bounce Detail', 'just_date'],
#       dtype='object')

# %%
big_frame['just_date'].resample('D').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-7e01a5b6fcbe> in <module>
# ----> 1 big_frame['just_date'].resample('D').mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1309     """
#    1310     tg = TimeGrouper(**kwds)
# -> 1311     return tg._get_resampler(obj, kind=kind)
#    1312
#    1313
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1474             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1475
# ...

# %%
big_frame['just_date']=pd.to_datetime(big_frame['just_date'], format='%Y-%M-%d')

# %%
big_frame['just_date']=big_frame['just_date'].strf

# %%
big_frame['just_date']
# Out:
# 6       2021-06-01
# 9       2021-06-01
# 35      2021-06-01
# 53      2021-06-01
# 65      2021-06-01
#            ...
# 37916   2021-06-21
# 37932   2021-06-21
# 37946   2021-06-21
# 37955   2021-06-21
# 37956   2021-06-21
# Name: just_date, Length: 4033, dtype: datetime64[ns]

# %%
big_frame.dtypes
# Out:
# Date                     object
# Email Address            object
# Sender                   object
# Subject                  object
# Status                   object
# Tags                    float64
# Subaccount               object
# Opens                     int64
# Clicks                    int64
# Bounce Detail            object
# just_date        datetime64[ns]
# dtype: object

# %%
big_frame.set_index('just_date', inplace=True)

# %%
big_frame.head()
# Out:
#                            Date                     Email Address  \
# just_date
# 2021-06-01  2021-06-01 14:37:37  brendarochellewilkie14@gmail.com
# 2021-06-01  2021-06-01 22:39:58                    ucools@msn.com
# 2021-06-01  2021-06-01 00:47:56            jennivicente@gmail.com
# 2021-06-01  2021-06-01 20:06:46          allison.killam@gmail.com
# 2021-06-01  2021-06-01 11:43:09                sdk.ll@yopmail.com
#
#                      Sender                              Subject Status  Tags  \
# just_date
# 2021-06-01  news@skidos.com  [Skidos] Please reset your password   sent   NaN
# 2021-06-01  news@skidos.com  [Skidos] Please reset your password   sent   NaN
# 2021-06-01  news@skidos.com  [Skidos] Please reset your password   sent   NaN
# 2021-06-01  news@skidos.com  [Skidos] Please reset your password   sent   NaN
# 2021-06-01  news@skidos.com  [Skidos] Please reset your password   sent   NaN
#
#                    Subaccount  Opens  Clicks Bounce Detail
# just_date
# ...

# %%
big_frame= big_frame.loc[big_frame["Subject"].str.contains('reset your password')]

# %%
big_frame.head()
# Out:
#                    Date                     Email Address           Sender  \
# 6   2021-06-01 14:37:37  brendarochellewilkie14@gmail.com  news@skidos.com
# 9   2021-06-01 22:39:58                    ucools@msn.com  news@skidos.com
# 35  2021-06-01 00:47:56            jennivicente@gmail.com  news@skidos.com
# 53  2021-06-01 20:06:46          allison.killam@gmail.com  news@skidos.com
# 65  2021-06-01 11:43:09                sdk.ll@yopmail.com  news@skidos.com
#
#                                 Subject Status  Tags         Subaccount  \
# 6   [Skidos] Please reset your password   sent   NaN  skidos_production
# 9   [Skidos] Please reset your password   sent   NaN  skidos_production
# 35  [Skidos] Please reset your password   sent   NaN  skidos_production
# 53  [Skidos] Please reset your password   sent   NaN  skidos_production
# 65  [Skidos] Please reset your password   sent   NaN  skidos_production
#
#     Opens  Clicks Bounce Detail  just_date
# ...

# %%
expected_df = big_frame[['just_date', 'Subject', 'Opens', 'Clicks']]
expected_df.head()
# Out:
#     just_date                              Subject  Opens  Clicks
# 6  2021-06-01  [Skidos] Please reset your password      2       1
# 9  2021-06-01  [Skidos] Please reset your password      0       0
# 35 2021-06-01  [Skidos] Please reset your password      2       1
# 53 2021-06-01  [Skidos] Please reset your password      3       1
# 65 2021-06-01  [Skidos] Please reset your password      0       0

# %%
expected_df.set_index('just_date', inplace=True)

# %%
import datetime
df = expected_df.groupby(pd.Grouper(level='just_date',freq='D'))

# %%
df['Subject'].value_counts()
# Out:
# just_date   Subject
# 2021-06-01  [Skidos] Please reset your password    175
# 2021-06-02  [Skidos] Please reset your password    128
# 2021-06-03  [Skidos] Please reset your password    123
# 2021-06-04  [Skidos] Please reset your password    127
# 2021-06-05  [Skidos] Please reset your password    134
# 2021-06-06  [Skidos] Please reset your password    170
# 2021-06-07  [Skidos] Please reset your password    121
# 2021-06-08  [Skidos] Please reset your password    117
# 2021-06-09  [Skidos] Please reset your password    123
# 2021-06-10  [Skidos] Please reset your password    118
# 2021-06-11  [Skidos] Please reset your password    223
# 2021-06-12  [Skidos] Please reset your password    236
# 2021-06-13  [Skidos] Please reset your password    307
# 2021-06-14  [Skidos] Please reset your password    282
# 2021-06-15  [Skidos] Please reset your password    242
# 2021-06-16  [Skidos] Please reset your password    206
# 2021-06-17  [Skidos] Please reset your password    300
# ...

# %%
df['Subject'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='just_date,Subject'>

# %%
df['Subject'].value_counts().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='just_date,Subject'>

# %%
day_wise_df = big_frame.groupby(['just_date'])
print(day_wise_df.groups).value_counts()
# Out:
# {2021-06-01 00:00:00: [2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-01 00:00:00, 2021-06-0
# ...

# %%
big_frame.describe()
# Out:
#        Tags        Opens       Clicks
# count   0.0  4033.000000  4033.000000
# mean    NaN     1.127697     0.470617
# std     NaN     1.279342     0.749465
# min     NaN     0.000000     0.000000
# 25%     NaN     0.000000     0.000000
# 50%     NaN     1.000000     0.000000
# 75%     NaN     2.000000     1.000000
# max     NaN    13.000000     8.000000

# %%
big_frame['Subject'].value_counts()
# Out:
# [Skidos] Please reset your password    4033
# Name: Subject, dtype: int64

# %%
big_frame['justdate']=pd.to_datetime(big_frame['just_date'], format = '%Y-%M-%d')
big_frame.set_index('justdate', inplace=True)
big_frame.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'just_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-75ee937d093c> in <module>
# ...

# %%
import pandas as pd
from datetime import timedelta, datetime

exports_activity_passing_no_parmaters =  pd.read_csv(r'D:\activity.csv')

exports_activity_passing_no_parmaters['Date'] =  pd.to_datetime(exports_activity_passing_no_parmaters['Date'])
exports_activity_passing_no_parmaters['just_date'] = exports_activity_passing_no_parmaters['Date'].dt.date
exports_activity_passing_no_parmaters.head()
# Out:
#                  Date               Email Address           Sender  \
# 0 2021-06-09 23:45:53   hersheykiss_843@yahoo.com  news@skidos.com
# 1 2021-05-26 03:20:29   restu_pratiwi81@yahoo.com  news@skidos.com
# 2 2021-06-18 13:07:33       mariasm01@hotmail.com  news@skidos.com
# 3 2021-06-15 16:48:03  majayoussef1996@icloud.com  news@skidos.com
# 4 2021-06-16 18:33:57      kellynsummer@yahoo.com  news@skidos.com
#
#                                          Subject        Status  Tags  \
# 0                             Welcome to Skidos!  soft-bounced   NaN
# 1                             Welcome to Skidos!          sent   NaN
# 2                        ¡Bienvenido/a a SKIDOS!          sent   NaN
# 3  [Skidos] Bitte setzen Sie ihr Passwort zurück          sent   NaN
# 4                          [Skidos] New password          sent   NaN
#
#           Subaccount  Opens  Clicks  \
# 0  skidos_production      0       0
# 1  skidos_production      0       0
# ...

# %%
# row in which 'Subject' is 'Please reset your password'
exports_activity_passing_no_parmaters = exports_activity_passing_no_parmaters.apply(lambda x : True
            if x['Subject'].str.contains('reset your password') else False, axis = 1)
  
# Count number of True in the series
num_rows = len(exports_activity_passing_no_parmaters[exports_activity_passing_no_parmaters == True].index)
  
print('Number of Rows in dataframe in which Subject conatins reset your password : ',
      num_rows )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-182-34feb436b483> in <module>
#       1 # row in which 'Subject' is 'Please reset your password'
# ----> 2 exports_activity_passing_no_parmaters = exports_activity_passing_no_parmaters.apply(lambda x : True
#       3             if x['Subject'].str.contains('reset your password') else False, axis = 1)
#       4
#       5 # Count number of True in the series
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# ...
